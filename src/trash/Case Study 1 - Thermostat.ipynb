# %% [markdown]
# # Thermostat
#
# Example taken from: Chaudhuri, S., & Solar-Lezama, A. (2010, June). Smooth interpretation. In Proceedings of the 31st ACM SIGPLAN Conference on Programming Language Design and Implementation (pp. 279-291).
#
# ```
# tOff = ?, tOn = ?
#
# repeat {
#     temp = readTemp()
#     if isOn() and temp > tOff {
#         isOn = False
#     }
#     else if not isOn() and temp < tOn {
#         isOn = True
#     }
# }
# ```
#
# Temperature evolves according to:
# $$ \frac{d \textit{temp}}{dt} = \begin{cases} -k \cdot \textit{temp} + h \, (+ \text{gauss}(0, \epsilon)) & \text{if isON} \\
#                                               -k \cdot \textit{temp} \, (+ \text{gauss}(0, \epsilon)) & \text{is not isOn}  \end{cases} $$
#
# I generate temperature trajectories for $tOn =, tOff=, k=, h=, \epsilon=$ and try to synthesize $tOn, tOff$ using as loss the log-likelihood over trajectories.

# %%
from sogaPreprocessor import *
from producecfg import *
from libSOGAsmoother import *
from time import time

torch.set_default_dtype(torch.float64)

# %% [markdown]
# ### Original model

# %%
def orig_model(T=10, init_T=17., tOn=18, tOff=20, k=0.01, h=0.5, eps=0.5):
    traj = torch.zeros(T)
    isOn = False
    traj[0] = 16.
    noise = distributions.Normal(torch.tensor(0.), torch.tensor(eps))
    
    for i in range(1,T):
        
        #update temperature
        if isOn:
            traj[i] = traj[i-1] -k*traj[i-1] + h + noise.rsample() 
        else:
            traj[i] = traj[i-1] -k*traj[i-1] + noise.rsample() 

        # update thermostat state
        if isOn and traj[i] > tOff:
            isOn = False
        elif not isOn and traj[i] < tOn:
            isOn = True
            
    return traj

# %%
# generation of a set of trajectories

import matplotlib.pyplot as plt

traj_set = []
for _ in range(100):
    traj_set.append(orig_model())
traj_set = torch.vstack(traj_set)

# plotting the first ten trajectories
for i in range(10):
    plt.plot(range(10), traj_set[i], color='grey')

plt.plot(range(10), torch.mean(traj_set, 0), lw=3, color='red', label='mean')
plt.legend()

# %% [markdown]
# ### SOGA program

# %%
compiledFile=compile2SOGA('../programs/SOGA/Optimization/Case Studies/Thermostat.soga')
cfg = produce_cfg(compiledFile)

pars = {'tOff':22., 'tOn':16.}

params_dict = {}
for key, value in pars.items():
    params_dict[key] = torch.tensor(value, requires_grad=True)    

output_dist = start_SOGA(cfg, params_dict)

# %%
output_dist.gm.mean()
# Out:
# tensor([16.0000, 15.8400, 15.9943, 16.2173, 16.4709, 16.7415, 17.0224, 17.3098,
#         17.6013, 17.8950, 18.4809, 18.4809,  0.8845, 18.4809],
#        grad_fn=<SumBackward1>)

# %%
import matplotlib.pyplot as plt

y_init = output_dist.gm.mean()[:10].detach()
plt.plot(range(10), y_init, lw=3, label='initial')

# plotting the first ten trajectories
for i in range(10):
    plt.plot(range(10), traj_set[i], color='grey')

plt.plot(range(10), torch.mean(traj_set, 0), lw=3, color='red', label='mean')
plt.legend()

# %%
def neg_log_likelihood(traj_set, dist):
    idx = [1,2,3,4,5,6,7,8,9]
    log_likelihood = torch.log(dist.gm.marg_pdf(traj_set[:, idx].unsqueeze(0), idx))
    return - torch.sum(log_likelihood)

def L2_distance(traj_set, dist):
    idx = [1,2,3,4,5,6,7,8,9]
    output_traj = dist.gm.mean()[idx]
    return torch.sum(torch.pow(traj_set[:, idx] - output_traj,2))

neg_log_likelihood(traj_set, output_dist)
# Out:
# tensor(752.9248, grad_fn=<NegBackward0>)

# %%
# Define the optimizer with init_mean as the parameter

#torch.autograd.set_detect_anomaly(True)
pars = {'tOff':22., 'tOn':16.}

params_dict = {}
for key, value in pars.items():
    params_dict[key] = torch.tensor(value, requires_grad=True)    

optimizer = torch.optim.Adam([params_dict[key] for key in params_dict.keys()], lr=0.05)

total_start = time()

for i in range(50):

    optimizer.zero_grad()  # Reset gradients
    
    # loss
    current_dist = start_SOGA(cfg, params_dict)

    loss = neg_log_likelihood(traj_set, current_dist)

    # Backpropagate
    loss.backward()
    
    optimizer.step()

    
    # Print progress
    if i % 10 == 0:
        out = ''
        for key in params_dict.keys():
            out = out + key + ': ' + str(params_dict[key].item()) + ' '
        out = out + f" loss: {loss.item()}"
        print(out)

total_end = time()

print('Optimization performed in ', round(total_end-total_start, 3))
# Out:
# tOff: 22.049999999885795 tOn: 16.04999999999771  loss: 752.9247828218605
# tOff: 22.53900245473786 tOn: 16.494602706567157  loss: 700.7309428415292
# tOff: 22.966836943759017 tOn: 16.78751261854624  loss: 691.334413785137
# tOff: 23.295917867355183 tOn: 16.951249528501595  loss: 689.6467802260252
# tOff: 23.530549196126984 tOn: 17.02338089922595  loss: 689.4549360131508
# Optimization performed in  46.395

# %%
params_dict
# Out:
# {'tOff': tensor(23.6820, requires_grad=True),
#  'tOn': tensor(17.0465, requires_grad=True)}

# %%
compiledFile=compile2SOGA('../programs/SOGA/Optimization/Case Studies/Thermostat.soga')
cfg = produce_cfg(compiledFile)
output_dist = start_SOGA(cfg, params_dict)

# %%
import matplotlib.pyplot as plt

# plotting the first ten trajectories
for i in range(10):
    plt.plot(range(10), traj_set[i], color='grey')

plt.plot(range(10), torch.mean(traj_set, 0), lw=3, color='red', label='mean')

plt.plot(range(10), y_init, lw=3, color='blue', label='initial traj')

plt.plot(range(10), output_dist.gm.mean()[:10].detach(), lw=3, color='green', label='optimized model')

plt.legend()

# %% [markdown]
# ## Profiling

# %%
compiledFile=compile2SOGA('../programs/SOGA/Optimization/Case Studies/Thermostat.soga')
cfg = produce_cfg(compiledFile)

pars = {'tOff':22., 'tOn':16.}

params_dict = {}
for key, value in pars.items():
    params_dict[key] = torch.tensor(value, requires_grad=True)    

import cProfile
import pstats

# Profile the code
profiler = cProfile.Profile()
profiler.enable()
output_dist = start_SOGA(cfg, params_dict)
profiler.disable()

# Create a Stats object
stats = pstats.Stats(profiler)

# Sort the stats by total time and print them
stats.sort_stats('cumtime').print_stats()
# Out:
#          323234 function calls (320406 primitive calls) in 0.786 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         2    0.000    0.000    0.786    0.393 c:\Users\birik\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3541(run_code)
#         2    0.000    0.000    0.786    0.393 {built-in method builtins.exec}
#         1    0.000    0.000    0.786    0.786 C:\Users\birik\AppData\Local\Temp\ipykernel_2840\3272690005.py:1(<module>)
#         1    0.001    0.001    0.786    0.786 c:\Users\birik\github\SOGA\src\libSOGA.py:36(start_SOGA)
#       227    0.007    0.000    0.784    0.003 c:\Users\birik\github\SOGA\src\libSOGA.py:64(SOGA)
#        88    0.002    0.000    0.453    0.005 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:218(truncate)
#        88    0.019    0.000    0.338    0.004 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:25(ineq_func)
#       116    0.001    0.000    0.307    0.003 c:\Users\birik\github\SOGA\src\libSOGAupdate.py:106(update_rule)
#        62    0.001    0.000    0.227    0.004 c:\Users\birik\github\SOGA\src\libSOGAupdate.py:94(asgmt_parse)
#        88    0.021    0.000    0.211    0.002 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:256(compute_moments)
#        62    0.001    0.000    0.152    0.002 c:\Users\birik\github\SOGA\src\ASGMTParser.py:139(assignment)
#        62    0.001    0.000    0.123    0.002 c:\Users\birik\github\SOGA\src\ASGMTParser.py:194(add)
#        88    0.001    0.000    0.113    0.001 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:232(trunc_parse)
#       116    0.001    0.000    0.111    0.001 c:\Users\birik\github\SOGA\src\ASGMTParser.py:265(add_term)
#      6621    0.005    0.000    0.102    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\BufferedTokenStream.py:109(sync)
#      1574    0.005    0.000    0.096    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\BufferedTokenStream.py:120(fetch)
#      2654    0.006    0.000    0.096    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\BufferedTokenStream.py:83(consume)
#      1574    0.010    0.000    0.091    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Lexer.py:114(nextToken)
#      1072    0.089    0.000    0.089    0.000 {built-in method torch.matmul}
#  2827/150    0.007    0.000    0.087    0.001 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\tree\Tree.py:143(walk)
#      1013    0.004    0.000    0.082    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\ParserATNSimulator.py:294(adaptivePredict)
#        80    0.029    0.000    0.080    0.001 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:335(compute_mom2)
#        62    0.017    0.000    0.079    0.001 c:\Users\birik\github\SOGA\src\libSOGAupdate.py:114(add_func)
#      1013    0.005    0.000    0.074    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\ParserATNSimulator.py:386(execATN)
#        88    0.001    0.000    0.072    0.001 c:\Users\birik\github\SOGA\src\TRUNCParser.py:157(trunc)
#      1403    0.003    0.000    0.067    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\tree\Tree.py:169(enterRule)
#      1424    0.005    0.000    0.063    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:94(match)
#      1424    0.015    0.000    0.056    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:137(execATN)
#      1424    0.004    0.000    0.053    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:345(consume)
#      1324    0.003    0.000    0.050    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:120(match)
#        88    0.001    0.000    0.048    0.001 c:\Users\birik\github\SOGA\src\TRUNCParser.py:226(ineq)
#       137    0.002    0.000    0.047    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:367(term)
#        80    0.012    0.000    0.046    0.001 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:324(compute_mom1)
#        88    0.008    0.000    0.046    0.001 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:312(prob)
#       150    0.011    0.000    0.038    0.000 c:\Users\birik\github\SOGA\src\libSOGAshared.py:241(extend_dist)
#       116    0.000    0.000    0.037    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:248(enterRule)
#       116    0.007    0.000    0.036    0.000 c:\Users\birik\github\SOGA\src\libSOGAupdate.py:52(enterAdd_term)
#      9778    0.009    0.000    0.033    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\CommonTokenStream.py:61(LT)
#        62    0.001    0.000    0.032    0.001 c:\Users\birik\github\SOGA\src\ASGMTParser.py:617(gm)
#       168    0.023    0.000    0.032    0.000 c:\Users\birik\github\SOGA\src\libSOGAshared.py:158(delete_zeros)
#       248    0.002    0.000    0.030    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\distributions\normal.py:53(__init__)
#       160    0.016    0.000    0.029    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\distributions\normal.py:80(log_prob)
#      1403    0.003    0.000    0.026    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:371(enterRule)
#       186    0.002    0.000    0.025    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:693(list_)
#       176    0.014    0.000    0.024    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\distributions\normal.py:94(cdf)
#     10791    0.003    0.000    0.021    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\BufferedTokenStream.py:185(lazyInit)
#      1447    0.007    0.000    0.020    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\error\ErrorStrategy.py:204(sync)
#        88    0.001    0.000    0.020    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:457(lexpr)
#       150    0.000    0.000    0.018    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\BufferedTokenStream.py:189(setup)
#        62    0.001    0.000    0.018    0.000 c:\Users\birik\github\SOGA\src\libSOGAupdate.py:31(unpack_rvs)
#       106    0.001    0.000    0.018    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:476(symvars)
#       248    0.005    0.000    0.017    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\distributions\distribution.py:41(__init__)
#        45    0.003    0.000    0.016    0.000 c:\Users\birik\github\SOGA\src\libSOGAmerge.py:16(merge)
#        88    0.003    0.000    0.015    0.000 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:245(find_basis)
#      1424    0.003    0.000    0.015    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Lexer.py:220(emit)
#        80    0.014    0.000    0.015    0.000 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:298(compute_lower_mom)
#        88    0.001    0.000    0.015    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:599(const)
#        88    0.001    0.000    0.014    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:534(monom)
#       186    0.005    0.000    0.013    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:682(unpack)
#        80    0.012    0.000    0.012    0.000 {built-in method torch._C._linalg.linalg_inv}
#   502/501    0.004    0.000    0.012    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\RuleContext.py:80(getText)
#       336    0.005    0.000    0.011    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\distributions\distribution.py:274(_validate_sample)
#      1574    0.003    0.000    0.011    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\CommonTokenFactory.py:46(create)
#        88    0.001    0.000    0.011    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:275(inop)
#      1424    0.004    0.000    0.011    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\ParserRuleContext.py:102(addTokenNode)
# 21033/20883    0.004    0.000    0.010    0.000 {built-in method builtins.len}
#      3817    0.002    0.000    0.010    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\CommonTokenStream.py:44(adjustSeekIndex)
#      3420    0.005    0.000    0.010    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:552(consume)
#      1403    0.003    0.000    0.009    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\tree\Tree.py:180(exitRule)
#        44    0.000    0.000    0.009    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:1089(par)
#      4844    0.005    0.000    0.009    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\dfa\DFAState.py:106(__eq__)
#       248    0.002    0.000    0.009    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\distributions\utils.py:24(broadcast_all)
#        88    0.001    0.000    0.008    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:676(var)
#       647    0.008    0.000    0.008    0.000 {built-in method torch.zeros}
#        88    0.008    0.000    0.008    0.000 {built-in method torch._C._linalg.linalg_svd}
#       832    0.008    0.000    0.008    0.000 {method 'all' of 'torch._C.TensorBase' objects}
#      1403    0.002    0.000    0.008    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:380(exitRule)
#      1997    0.001    0.000    0.008    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\ParserRuleContext.py:156(getTypedRuleContext)
#       473    0.008    0.000    0.008    0.000 {built-in method torch.tensor}
#      3817    0.005    0.000    0.008    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\BufferedTokenStream.py:205(nextTokenOnChannel)
#      1729    0.004    0.000    0.008    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\IntervalSet.py:89(__contains__)
#      1574    0.005    0.000    0.008    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Token.py:76(__init__)
#      9688    0.008    0.000    0.008    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\InputStream.py:48(LA)
#        88    0.000    0.000    0.008    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:209(enterRule)
#      4224    0.003    0.000    0.008    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\BufferedTokenStream.py:149(LA)
#        88    0.001    0.000    0.007    0.000 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:178(enterIneq)
#        88    0.000    0.000    0.007    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:517(enterRule)
#      1997    0.004    0.000    0.007    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\ParserRuleContext.py:114(getChild)
#        88    0.003    0.000    0.007    0.000 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:191(enterMonom)
#      1017    0.001    0.000    0.006    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\tree\Tree.py:115(getText)
#       900    0.003    0.000    0.006    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\_tensor.py:1083(__len__)
#       256    0.006    0.000    0.006    0.000 {built-in method torch.where}
#       400    0.001    0.000    0.006    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\_tensor.py:33(wrapped)
#       406    0.006    0.000    0.006    0.000 {built-in method torch.vstack}
#       150    0.000    0.000    0.006    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\InputStream.py:17(__init__)
#       604    0.006    0.000    0.006    0.000 {method 'view' of 'torch._C.TensorBase' objects}
#      1017    0.004    0.000    0.006    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Token.py:110(text)
#       648    0.005    0.000    0.005    0.000 {method 'unsqueeze' of 'torch._C.TensorBase' objects}
#       150    0.001    0.000    0.005    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\InputStream.py:22(_loadString)
#       400    0.005    0.000    0.005    0.000 {method 'pow' of 'torch._C.TensorBase' objects}
#       584    0.005    0.000    0.005    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\distributions\constraints.py:355(check)
#       248    0.003    0.000    0.005    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\functional.py:47(broadcast_tensors)
#     18482    0.004    0.000    0.005    0.000 {built-in method builtins.isinstance}
#       266    0.005    0.000    0.005    0.000 {built-in method torch.hstack}
#       292    0.005    0.000    0.005    0.000 {built-in method torch.sum}
#        88    0.001    0.000    0.005    0.000 c:\Users\birik\github\SOGA\src\TRUNCLexer.py:103(__init__)
#      4844    0.005    0.000    0.005    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:206(getExistingTargetState)
#       150    0.001    0.000    0.005    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:226(computeTargetState)
#        62    0.000    0.000    0.005    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:177(enterRule)
#       150    0.001    0.000    0.005    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\InputStream.py:24(<listcomp>)
#      2748    0.002    0.000    0.005    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:312(getCurrentToken)
#        62    0.000    0.000    0.005    0.000 c:\Users\birik\github\SOGA\src\libSOGAupdate.py:40(enterAdd)
#     13070    0.004    0.000    0.005    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\ParserRuleContext.py:126(getChildren)
#        88    0.001    0.000    0.004    0.000 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:144(parse_const)
#      1424    0.002    0.000    0.004    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\tree\Tree.py:85(__init__)
#      1424    0.002    0.000    0.004    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:245(failOrAccept)
#        62    0.000    0.000    0.004    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:122(enterRule)
#        62    0.000    0.000    0.004    0.000 c:\Users\birik\github\SOGA\src\libSOGAupdate.py:36(enterAssignment)
#      1403    0.002    0.000    0.004    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\ParserRuleContext.py:38(__init__)
#        88    0.001    0.000    0.004    0.000 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:127(__init__)
#        80    0.003    0.000    0.004    0.000 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:12(normalize_weights)
#        88    0.001    0.000    0.004    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:113(__init__)
#      1013    0.001    0.000    0.004    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\BufferedTokenStream.py:75(seek)
#       248    0.004    0.000    0.004    0.000 {built-in method torch.sqrt}
#      3420    0.003    0.000    0.004    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:472(captureSimState)
#      6840    0.004    0.000    0.004    0.000 {built-in method builtins.ord}
#      4272    0.004    0.000    0.004    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\tree\Tree.py:88(__setattr__)
#       150    0.001    0.000    0.004    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:60(__init__)
#        62    0.000    0.000    0.004    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:181(exitRule)
#       300    0.001    0.000    0.004    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Recognizer.py:36(checkVersion)
#       336    0.004    0.000    0.004    0.000 {built-in method torch.ones}
#      3420    0.003    0.000    0.004    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\ATNConfigSet.py:138(__eq__)
#        62    0.001    0.000    0.004    0.000 c:\Users\birik\github\SOGA\src\ASGMTLexer.py:89(__init__)
#        62    0.002    0.000    0.003    0.000 c:\Users\birik\github\SOGA\src\libSOGAupdate.py:87(exitAdd)
#       106    0.000    0.000    0.003    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:465(getVar)
#        12    0.000    0.000    0.003    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:554(idd)
#       407    0.003    0.000    0.003    0.000 {method 'reshape' of 'torch._C.TensorBase' objects}
#      1729    0.001    0.000    0.003    0.000 {built-in method builtins.any}
#      2243    0.003    0.000    0.003    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\ParserATNSimulator.py:483(getExistingTargetState)
#      1403    0.002    0.000    0.003    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\CommonTokenStream.py:47(LB)
#       248    0.003    0.000    0.003    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\distributions\constraints.py:368(check)
#        62    0.000    0.000    0.003    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:95(__init__)
#       600    0.002    0.000    0.003    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Recognizer.py:24(extractVersion)
#       150    0.002    0.000    0.003    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:66(__init__)
#      2677    0.002    0.000    0.003    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\ParserRuleContext.py:88(addChild)
#       150    0.001    0.000    0.003    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:259(getReachableConfigSet)
#      1403    0.001    0.000    0.003    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:363(addContextToParseTree)
#       168    0.000    0.000    0.003    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:352(is_const)
#       248    0.003    0.000    0.003    0.000 {method 'squeeze' of 'torch._C.TensorBase' objects}
#      1424    0.002    0.000    0.003    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:285(accept)
#      4453    0.003    0.000    0.003    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\IntervalSet.py:93(<genexpr>)
#       382    0.002    0.000    0.002    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\ParserRuleContext.py:159(getTypedRuleContexts)
#       168    0.000    0.000    0.002    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:335(is_var)
#       496    0.001    0.000    0.002    0.000 {built-in method builtins.all}
#       900    0.002    0.000    0.002    0.000 {built-in method torch._C._get_tracing_state}
#       176    0.002    0.000    0.002    0.000 {method 'reciprocal' of 'torch._C.TensorBase' objects}
#       160    0.002    0.000    0.002    0.000 {method 'log' of 'torch._C.TensorBase' objects}
#       160    0.002    0.000    0.002    0.000 {method 'exp' of 'torch._C.TensorBase' objects}
#      1403    0.002    0.000    0.002    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\RuleContext.py:39(__init__)
#      6930    0.002    0.000    0.002    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Recognizer.py:143(state)
#       186    0.000    0.000    0.002    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:590(list_)
#        88    0.002    0.000    0.002    0.000 {built-in method torch._C._linalg.linalg_norm}
#       124    0.002    0.000    0.002    0.000 {built-in method torch.clone}
#       270    0.001    0.000    0.002    0.000 c:\Users\birik\github\SOGA\src\libSOGA.py:26(update_child)
#      3420    0.002    0.000    0.002    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\InputStream.py:42(consume)
#       176    0.002    0.000    0.002    0.000 {built-in method torch.erf}
#      1447    0.001    0.000    0.002    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\ATN.py:69(nextTokens)
#      1403    0.002    0.000    0.002    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:388(enterOuterAlt)
#        88    0.000    0.000    0.002    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:669(_getText)
#        62    0.002    0.000    0.002    0.000 {built-in method torch.cat}
#       256    0.002    0.000    0.002    0.000 {method 't' of 'torch._C.TensorBase' objects}
#        44    0.002    0.000    0.002    0.000 c:\Users\birik\github\SOGA\src\libSOGAmerge.py:37(<listcomp>)
#        81    0.002    0.000    0.002    0.000 {built-in method torch.eye}
#       248    0.002    0.000    0.002    0.000 {built-in method torch.broadcast_tensors}
#       150    0.000    0.000    0.002    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:297(setInputStream)
#      7992    0.002    0.000    0.002    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\InputStream.py:27(index)
#       150    0.001    0.000    0.002    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Lexer.py:226(emitEOF)
#       150    0.001    0.000    0.002    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Lexer.py:46(__init__)
#      1574    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Token.py:36(__init__)
#      1424    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\error\ErrorStrategy.py:97(reportMatch)
#        62    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:111(symvars)
#       150    0.000    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:304(setTokenStream)
#       264    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:202(const)
#      2806    0.001    0.000    0.001    0.000 {built-in method builtins.hasattr}
#       440    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\ParserRuleContext.py:133(getToken)
#       310    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:314(gm)
#      1424    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Lexer.py:259(getCharIndex)
#        88    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:440(enterRule)
#      6201    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#        62    0.001    0.000    0.001    0.000 {built-in method torch.diag}
#       150    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:91(reset)
#       134    0.001    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:238(term)
#       744    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\distributions\utils.py:40(<genexpr>)
#       408    0.000    0.000    0.001    0.000 <frozen abc>:117(__instancecheck__)
#       142    0.001    0.000    0.001    0.000 {method 'expand' of 'torch._C.TensorBase' objects}
#      1017    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\InputStream.py:78(getText)
#      1424    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:294(getInputStream)
#       308    0.000    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:297(getReachableTarget)
#       186    0.001    0.000    0.001    0.000 {built-in method torch.empty}
#        62    0.001    0.000    0.001    0.000 {built-in method torch.all}
#        88    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:183(enterLexpr)
#       300    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:310(symvars)
#        62    0.001    0.000    0.001    0.000 {built-in method torch.pow}
#       176    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:506(var)
#        80    0.001    0.000    0.001    0.000 {method 'transpose' of 'torch._C.TensorBase' objects}
#        62    0.001    0.000    0.001    0.000 {method 'flatten' of 'torch._C.TensorBase' objects}
#       150    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\ParserATNSimulator.py:269(__init__)
#        62    0.001    0.000    0.001    0.000 {built-in method torch.prod}
#        44    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:1081(getValue)
#        44    0.001    0.000    0.001    0.000 {built-in method torch.stack}
#       230    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:299(NUM)
#      2850    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Recognizer.py:132(state)
#      1574    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:42(reset)
#      1447    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\ATN.py:62(nextTokensNoContext)
#      1500    0.001    0.000    0.001    0.000 {method 'find' of 'str' objects}
#      1403    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\BufferedTokenStream.py:221(previousTokenOnChannel)
#       408    0.001    0.000    0.001    0.000 {built-in method _abc._abc_instancecheck}
#       300    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Recognizer.py:19(__init__)
#      1256    0.001    0.000    0.001    0.000 {method 'size' of 'torch._C.TensorBase' objects}
#       992    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\overrides.py:1958(is_tensor_like)
#        31    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:355(getValue)
#       150    0.000    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\ATNConfigSet.py:211(__init__)
#      1574    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\error\ErrorStrategy.py:87(endErrorCondition)
#        62    0.001    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\libSOGAshared.py:253(<listcomp>)
#      2871    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\error\ErrorStrategy.py:78(inErrorRecoveryMode)
#       150    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\ATNConfigSet.py:65(__iter__)
#       137    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:295(__init__)
#       186    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:649(__init__)
#      1424    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\InputStream.py:71(seek)
#       132    0.000    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\Transition.py:197(matches)
#       150    0.000    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\CommonTokenStream.py:40(__init__)
#        88    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:198(inop)
#      2871    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:300(getTokenStream)
#        88    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:125(__init__)
#       140    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:444(idd)
#       496    0.000    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\distributions\constraints.py:149(is_dependent)
#       137    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:306(sub)
#       744    0.000    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\distributions\utils.py:45(<genexpr>)
#       248    0.000    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\torch\_VF.py:27(__getattr__)
#        62    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\libSOGAshared.py:251(<listcomp>)
#      2998    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\InputStream.py:62(mark)
#        62    0.001    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\libSOGAshared.py:256(<listcomp>)
#      1724    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Lexer.py:242(line)
#        80    0.000    0.000    0.001    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:167(add_term)
#      2998    0.001    0.000    0.001    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\InputStream.py:65(release)
#       150    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\error\ErrorStrategy.py:43(__init__)
#      1574    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Lexer.py:211(emitToken)
#       182    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\producecfg.py:48(set_dist)
#        62    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:107(__init__)
#        62    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\libSOGAshared.py:259(<listcomp>)
#       132    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:568(NUM)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:648(gm)
#      2806    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\RuleContext.py:67(getRuleContext)
#       502    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\ParserRuleContext.py:170(getChildCount)
#       106    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:437(__init__)
#      1724    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Lexer.py:250(column)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:412(__init__)
#       116    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:234(__init__)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:156(parse_monom_const)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:190(__init__)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:250(__init__)
#       150    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\ATNConfigSet.py:36(__init__)
#       106    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:302(par)
#      1017    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Token.py:67(getInputStream)
#       900    0.000    0.000    0.000    0.000 {method 'dim' of 'torch._C.TensorBase' objects}
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:637(__init__)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:502(__init__)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:644(idd)
#        40    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\jax\_src\lib\__init__.py:101(_xla_gc_callback)
#       194    0.000    0.000    0.000    0.000 {method 'index' of 'list' objects}
#       502    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#       336    0.000    0.000    0.000    0.000 {built-in method math.sqrt}
#       502    0.000    0.000    0.000    0.000 {method '__exit__' of '_io._IOBase' objects}
#       137    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:321(enterRule)
#       150    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:39(__init__)
#       160    0.000    0.000    0.000    0.000 {built-in method math.log}
#       748    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:564(__init__)
#       186    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:668(enterRule)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:444(exitRule)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:510(const)
#        62    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:586(__init__)
#        62    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:163(__init__)
#       921    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#       186    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:672(exitRule)
#        62    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:126(exitRule)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:571(par)
#       150    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:572(setTrace)
#      1017    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\InputStream.py:31(size)
#       900    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function_unary}
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:140(enterRule)
#       106    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:451(enterRule)
#        62    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\libSOGAupdate.py:16(__init__)
#      1403    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\RuleContext.py:105(setAltNumber)
#       249    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\libSOGAshared.py:47(__init__)
#       150    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\BufferedTokenStream.py:32(__init__)
#      1403    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\tree\Tree.py:74(enterEveryRule)
#        40    0.000    0.000    0.000    0.000 {built-in method jaxlib.xla_extension.collect_garbage}
#        44    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:104(negate)
#        44    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:1057(__init__)
#       150    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\error\ErrorStrategy.py:66(reset)
#       648    0.000    0.000    0.000    0.000 {built-in method torch._C._has_torch_function}
#      1424    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\tree\Tree.py:68(visitTerminal)
#       137    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:325(exitRule)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:586(exitRule)
#       300    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\ATNSimulator.py:39(__init__)
#       227    0.000    0.000    0.000    0.000 {method 'pop' of 'list' objects}
#      1403    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\tree\Tree.py:77(exitEveryRule)
#       150    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\PredictionContext.py:86(__init__)
#       116    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:252(exitRule)
#       106    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:455(exitRule)
#        34    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:513(IDV)
#      1013    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\BufferedTokenStream.py:65(mark)
#       186    0.000    0.000    0.000    0.000 {method 'split' of 'str' objects}
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:144(exitRule)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:655(enterRule)
#      1013    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\BufferedTokenStream.py:68(release)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:521(exitRule)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:258(enterRule)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:213(exitRule)
#        44    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:441(IDV)
#        44    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:575(idd)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:659(exitRule)
#       124    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\libSOGAshared.py:52(n_comp)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:582(enterRule)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\libSOGAtruncate.py:187(exitLexpr)
#       124    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\libSOGAshared.py:55(n_dim)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:262(exitRule)
#        62    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:600(enterRule)
#        11    0.000    0.000    0.000    0.000 {method 'item' of 'torch._C.TensorBase' objects}
#       181    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\producecfg.py:51(set_p)
#        62    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:604(exitRule)
#       150    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\ATNConfigSet.py:164(__len__)
#       248    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#        44    0.000    0.000    0.000    0.000 {method 'replace' of 'str' objects}
#       187    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\libSOGAshared.py:168(__init__)
#       150    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\LexerATNSimulator.py:478(addDFAEdge)
#        44    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:1067(enterRule)
#        44    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCParser.py:1071(exitRule)
#         2    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\codeop.py:117(__call__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.compile}
#       181    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\producecfg.py:54(set_trunc)
#       150    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\Parser.py:208(removeParseListener)
#        12    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:509(__init__)
#       186    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTListener.py:79(exitList)
#       106    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTListener.py:48(enterSymvars)
#        12    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:525(enterRule)
#       186    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTListener.py:75(enterList)
#        44    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\Transition.py:84(matches)
#       137    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTListener.py:39(enterTerm)
#       132    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\antlr4\atn\Transition.py:114(matches)
#        12    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTParser.py:529(exitRule)
#       137    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTListener.py:43(exitTerm)
#       116    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTListener.py:34(exitAdd_term)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCListener.py:12(enterTrunc)
#       106    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTListener.py:52(exitSymvars)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCListener.py:79(exitConst)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCListener.py:25(exitIneq)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCListener.py:30(enterInop)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCListener.py:70(exitMonom)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCListener.py:84(enterVar)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCListener.py:75(enterConst)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCListener.py:34(exitInop)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCListener.py:88(exitVar)
#        88    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCListener.py:16(exitTrunc)
#         2    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\traitlets\traitlets.py:676(__get__)
#         2    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\contextlib.py:132(__enter__)
#         2    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\contextlib.py:287(helper)
#        62    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTListener.py:16(exitAssignment)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        62    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTListener.py:70(exitGm)
#        62    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTListener.py:66(enterGm)
#         2    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\contextlib.py:104(__init__)
#        44    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCListener.py:142(exitPar)
#        44    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\TRUNCListener.py:138(enterPar)
#         2    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\contextlib.py:141(__exit__)
#         4    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\IPython\core\compilerop.py:180(extra_flags)
#         2    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\traitlets\traitlets.py:629(get)
#         2    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:3493(compare)
#         2    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:1277(user_global_ns)
#        12    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTListener.py:61(exitIdd)
#        12    0.000    0.000    0.000    0.000 c:\Users\birik\github\SOGA\src\ASGMTListener.py:57(enterIdd)
#         4    0.000    0.000    0.000    0.000 c:\Users\birik\anaconda3\Lib\typing.py:2256(cast)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# Define the optimizer with init_mean as the parameter

from time import time
forward_time = []
loss_time = []
backward_time = []

#torch.autograd.set_detect_anomaly(True)
pars = {'tOff':22., 'tOn':16.}

params_dict = {}
for key, value in pars.items():
    params_dict[key] = torch.tensor(value, requires_grad=True)    

optimizer = torch.optim.Adam([params_dict[key] for key in params_dict.keys()], lr=0.05)

total_start = time()

for i in range(50):

    optimizer.zero_grad()  # Reset gradients
    
    # loss
    start = time()
    current_dist = start_SOGA(cfg, params_dict)
    end = time()
    forward_time.append(end-start)

    start = time()
    loss = neg_log_likelihood(traj_set, current_dist)
    end = time()
    loss_time.append(end-start)
        
    # Backpropagate
    start = time()
    loss.backward()
    end = time()
    backward_time.append(end-start)
    
    # Update init_mean
    optimizer.step()

    #with torch.no_grad():
    #    params_dict['std'].clamp_(0.001, 1e10)
    
    # Print progress
    if i % 10 == 0:
        out = ''
        for key in params_dict.keys():
            out = out + key + ': ' + str(params_dict[key].item()) + ' '
        out = out + f" loss: {loss.item()}"
        print(out)

total_end = time()

print('Optimization performed in ', round(total_end-total_start, 3))

print('Time for forward computation', torch.mean(torch.tensor(forward_time)))
print('Time for loss computation', torch.mean(torch.tensor(loss_time)))
print('Time for backward computation', torch.mean(torch.tensor(backward_time)))
# Out:
# tOff: 22.049999999776816 tOn: 16.049999999997763  loss: 662.8671946531208
# tOff: 22.529580042763488 tOn: 16.4743864981192  loss: 618.497552194787
# tOff: 22.88229461145147 tOn: 16.744070480210603  loss: 610.8906846162685
# tOff: 23.063329693354248 tOn: 16.914232370363194  loss: 609.0879554985543
# tOff: 23.133764834845064 tOn: 16.988469469136255  loss: 609.1169905648284
# Optimization performed in  38.277
# Time for forward computation tensor(0.4412)
# Time for loss computation tensor(0.0269)
# Time for backward computation tensor(0.2967)

# %%
print('Total time for forward computation', torch.sum(torch.tensor(forward_time)))
print('Total time for loss computation', torch.sum(torch.tensor(loss_time)))
print('Total time for backward computation', torch.sum(torch.tensor(backward_time)))
# Out:
# Total time for forward computation tensor(22.0588)
# Total time for loss computation tensor(1.3459)
# Total time for backward computation tensor(14.8360)

# %%
#### Before optimization
'''
Total time for forward computation tensor(56.8369)
Total time for loss computation tensor(1.6743)
Total time for backward computation tensor(25.0452)
'''
# Out:
# '\nTotal time for forward computation tensor(56.8369)\nTotal time for loss computation tensor(1.6743)\nTotal time for backward computation tensor(25.0452)\n'

# %%
plt.plot(range(len(forward_time)), forward_time, label='forward')
plt.plot(range(len(loss_time)), loss_time, label='loss')
plt.plot(range(len(backward_time)), backward_time, label='backward')
plt.legend()
